# %%
from pathlib import Path
import pandas as pd

raw_dir = Path("../data/raw")

files = [
    "disaster_declarations_summaries.csv",
    "public_assistance_funded_projects_details.csv",
    "fema_web_disaster_summaries.csv",
]

for file_name in files:
    file_path = raw_dir / file_name
    print(f"\nChecking {file_name}")
    print("Exists:", file_path.exists())

    if file_path.exists():
        df = pd.read_csv(file_path)
        print("Shape:", df.shape)
        print("Columns:", len(df.columns))
        display(df.head(2))
# Out:
# Checking disaster_declarations_summaries.csv
# Exists: True
# Shape: (69770, 28)
# Columns: 28
#   femaDeclarationString  disasterNumber state declarationType  \
# 0            FM-5529-OR            5529    OR              FM
# 1            FM-5528-OR            5528    OR              FM
#
#             declarationDate  fyDeclared incidentType declarationTitle  \
# 0  2024-08-09T00:00:00.000Z        2024         Fire   LEE FALLS FIRE
# 1  2024-08-06T00:00:00.000Z        2024         Fire    ELK LANE FIRE
#
#    ihProgramDeclared  iaProgramDeclared  ...  placeCode       designatedArea  \
# 0              False              False  ...      99067  Washington (County)
# 1              False              False  ...      99031   Jefferson (County)
#
#   declarationRequestNumber lastIAFilingDate  incidentId  region  \
# 0                    24122              NaN  2024081001      10
# 1                    24116              NaN  2024080701      10
#
# ...

# %%
import pandas as pd

df_decl = pd.read_csv("../data/raw/disaster_declarations_summaries.csv")
df_pa = pd.read_csv("../data/raw/public_assistance_funded_projects_details.csv")
df_sum = pd.read_csv("../data/raw/fema_web_disaster_summaries.csv")

print("Declarations:", df_decl.shape)
print("Public Assistance:", df_pa.shape)
print("Summaries:", df_sum.shape)

print("\nKey column check:")
print("disasterNumber in declarations:", "disasterNumber" in df_decl.columns)
print("disasterNumber in PA:", "disasterNumber" in df_pa.columns)
print("disasterNumber in summaries:", "disasterNumber" in df_sum.columns)
# Out:
# Declarations: (69770, 28)
# Public Assistance: (810787, 25)
# Summaries: (3909, 14)
#
# Key column check:
# disasterNumber in declarations: True
# disasterNumber in PA: True
# disasterNumber in summaries: True
